# %%
# !python scripts/run_review5_experiments.py sasrec-quality --dataset amazon
# Out:
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 42: NDCG@10 0.0000 vs popularity 0.0074
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 43: NDCG@10 0.0004 vs popularity 0.0074
# [sasrec-quality] seed 44: NDCG@10 0.0000 vs popularity 0.0074
# [sasrec-quality] seed 45: NDCG@10 0.0003 vs popularity 0.0074
# ...

# %%
# !python scripts/run_review5_experiments.py sasrec-quality --dataset movielens
# Out:
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 42: NDCG@10 0.0010 vs popularity 0.0191
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 43: NDCG@10 0.0022 vs popularity 0.0191
# [sasrec-quality] seed 44: NDCG@10 0.0007 vs popularity 0.0191
# [sasrec-quality] seed 45: NDCG@10 0.0033 vs popularity 0.0191
# ...

# %%
# !python scripts/run_review5_experiments.py lime-masks --dataset amazon
# Out:
# [lime-masks] 25/200 users done
# [lime-masks] 50/200 users done
# [lime-masks] 75/200 users done
# [lime-masks] 100/200 users done
# [lime-masks] 125/200 users done
# [lime-masks] 150/200 users done
# [lime-masks] 175/200 users done
# [lime-masks] 200/200 users done
# Traceback (most recent call last):
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 413, in <module>
#     main()
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 409, in main
#     args.func(args)
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 135, in cmd_lime_masks
#     save(Path(args.out), f"lime_mask_ablation_{args.dataset}.json", payload)
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 89, in save
# ...

# %%
# !python scripts/run_review5_experiments.py lime-masks --dataset movielens
# Out:
# [lime-masks] 25/200 users done
# [lime-masks] 50/200 users done
# [lime-masks] 75/200 users done
# [lime-masks] 100/200 users done
# [lime-masks] 125/200 users done
# [lime-masks] 150/200 users done
# [lime-masks] 175/200 users done
# [lime-masks] 200/200 users done
# wrote results/review5/lime_mask_ablation_movielens.json

# %%
# !python scripts/run_review5_experiments.py exact-dist --dataset amazon
# Out:
# [exact-dist] 25 enumerated users
# [exact-dist] 50 enumerated users
# [exact-dist] 75 enumerated users
# [exact-dist] 100 enumerated users
# [exact-dist] 125 enumerated users
# [exact-dist] 150 enumerated users
# [exact-dist] 175 enumerated users
# [exact-dist] 200 enumerated users
# [exact-dist] 225 enumerated users
# [exact-dist] 250 enumerated users
# [exact-dist] 275 enumerated users
# [exact-dist] 300 enumerated users
# wrote results/review5/exact_shapley_distribution_amazon.json

# %%
# !python scripts/run_review5_experiments.py exact-dist --dataset movielens
# Out:
# [exact-dist] 25 enumerated users
# [exact-dist] 50 enumerated users
# wrote results/review5/exact_shapley_distribution_movielens.json

# %%
# !python scripts/run_review5_experiments.py convergence-quantiles --raw results/raw/convergence_seed42.json
# Out:
# Traceback (most recent call last):
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 413, in <module>
#     main()
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 409, in main
#     args.func(args)
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 324, in cmd_convergence_quantiles
#     raw = json.loads(Path(args.raw).read_text())
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.13_4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pathlib.py", line 1027, in read_text
#     with self.open(mode='r', encoding=encoding, errors=errors) as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python scripts/run_review5_experiments.py variance-components --dataset amazon
# Out:
# [variance] fixed model, attribution seed 42 done
# [variance] fixed model, attribution seed 43 done
# [variance] fixed model, attribution seed 44 done
# [variance] fixed model, attribution seed 45 done
# [variance] fixed model, attribution seed 46 done
# [variance] model seed 42 done
# [variance] model seed 43 done
# [variance] model seed 44 done
# [variance] model seed 45 done
# [variance] model seed 46 done
# wrote results/review5/variance_components_amazon.json

# %%
# !python scripts/run_review5_experiments.py variance-components --dataset movielens
# Out:
# [variance] fixed model, attribution seed 42 done
# [variance] fixed model, attribution seed 43 done
# [variance] fixed model, attribution seed 44 done
# [variance] fixed model, attribution seed 45 done
# [variance] fixed model, attribution seed 46 done
# [variance] model seed 42 done
# [variance] model seed 43 done
# [variance] model seed 44 done
# [variance] model seed 45 done
# [variance] model seed 46 done
# wrote results/review5/variance_components_movielens.json

# %%
# %%bash
# for seed in 42 43 44 45 46; do
#   python scripts/run_recommendation.py \
#     --ratings data/amazon-digital-music/interactions.csv \
#     --dataset-format csv --dataset-name Amazon-Digital-Music \
#     --full-catalog --max-users 1000 \
#     --analysis-role full_catalogue --condition full_catalogue \
#     --seed $seed --output results/raw/amazon_full_catalogue_1000_seed${seed}.json
# done
# Out:
# {
#   "status": "paper_eligible",
#   "gate": {
#     "users": 200,
#     "changed_fraction": 0.795,
#     "mean_abs_ndcg_change": 0.054293821711756035,
#     "static_changed_fraction": 0.0,
#     "static_mean_abs_ndcg_change": 0.0,
#     "dynamic_pass": true,
#     "static_pass": true,
#     "passed": true,
#     "evaluation_mode": "fixed_sampled_gate",
#     "evaluation_size": 200,
#     "minimum_required_users": 200,
#     "sample_size_pass": true,
#     "blocking_required": true
#   },
#   "metrics": {
#     "aia": {
#       "shapley_mc": {
#         "mean": -0.04734812831111548,
#         "median": 0.0,
#         "n": 999,
#         "missing": 1
#       },
#       "loo": {
#         "mean": 0.7779168688186032,
#         "median": 0.8999999999999998,
#         "n": 999,
#         "missing": 1
#       },
#       "lime": {
#         "mean": 0.7112026833056426,
#         "median": 0.7999999999999999,
#         "n": 999,
#         "missing": 1
#       },
#       "greedy_cf": {
# ...

# %%
# !python scripts/run_review5_experiments.py sasrec-quality --dataset amazon    --train-all --epochs 30
# Out:
# [sasrec-quality] training on all 7621 eligible users
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 42: NDCG@10 0.0003 vs popularity 0.0074
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 43: NDCG@10 0.0000 vs popularity 0.0074
# [sasrec-quality] seed 44: NDCG@10 0.0000 vs popularity 0.0074
# ...

# %%
# !python scripts/run_review5_experiments.py sasrec-quality --dataset movielens --train-all --epochs 30
# Out:
# [sasrec-quality] training on all 6028 eligible users
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 42: NDCG@10 0.0016 vs popularity 0.0191
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 43: NDCG@10 0.0018 vs popularity 0.0191
# [sasrec-quality] seed 44: NDCG@10 0.0017 vs popularity 0.0191
# ...

# %%
# !python scripts/run_review5_experiments.py lime-masks --dataset amazon
# Out:
# [lime-masks] 25/200 users done
# [lime-masks] 50/200 users done
# [lime-masks] 75/200 users done
# [lime-masks] 100/200 users done
# [lime-masks] 125/200 users done
# [lime-masks] 150/200 users done
# [lime-masks] 175/200 users done
# [lime-masks] 200/200 users done
# wrote results/review5/lime_mask_ablation_amazon.json

# %%
# !python scripts/run_review5_experiments.py sasrec-quality --dataset amazon    --train-all --epochs 30
# Out:
# [sasrec-quality] training on all 7621 eligible users
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 42: NDCG@10 0.0000 vs popularity 0.0074
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 43: NDCG@10 0.0007 vs popularity 0.0074
# [sasrec-quality] seed 44: NDCG@10 0.0000 vs popularity 0.0074
# ...

# %%
# !python scripts/run_review5_experiments.py sasrec-quality --dataset movielens --train-all --epochs 30
# Out:
# [sasrec-quality] training on all 6028 eligible users
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 42: NDCG@10 0.0011 vs popularity 0.0191
# /Users/mlouhichi/Desktop/actionShap/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [sasrec-quality] seed 43: NDCG@10 0.0011 vs popularity 0.0191
# [sasrec-quality] seed 44: NDCG@10 0.0013 vs popularity 0.0191
# ...

# %%
# !python scripts/run_review5_experiments.py convergence-quantiles --raw results/raw/convergence_seed42.json
# Out:
# Traceback (most recent call last):
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 444, in <module>
#     main()
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 440, in main
#     args.func(args)
#   File "/Users/mlouhichi/Desktop/actionShap/next-paper/paper-ideas/ActionShap/code/scripts/run_review5_experiments.py", line 352, in cmd_convergence_quantiles
#     raw = json.loads(Path(args.raw).read_text())
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.13_4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pathlib.py", line 1027, in read_text
#     with self.open(mode='r', encoding=encoding, errors=errors) as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
